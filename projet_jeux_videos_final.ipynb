# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
achievements_playstation = pd.read_csv("playstation/achievements.csv")
achievements_playstation.head()
# Out:
#     achievementid  gameid                 title           description  \
# 0  749980_6103480  749980          Platinum Cup  Get all the trophies
# 1  749980_6103481  749980       Arcade Beginner           Finish race
# 2  749980_6103482  749980  Arcade Beginner Dirt           Finish race
# 3  749980_6103483  749980   Arcade Intermediate           Finish race
# 4  749980_6103484  749980       Arcade Advanced           Finish race
#
#      rarity
# 0  Platinum
# 1    Bronze
# 2    Bronze
# 3    Silver
# 4    Silver

# %%
games_playstation = pd.read_csv("playstation/games.csv")
games_playstation.head()
# Out:
#    gameid                    title platform           developers  \
# 0  749375    Medieval Match Master      PS4       ['Erik Games']
# 1  749839  Sunforge Solar Survival      PS4     ['GrizzlyGames']
# 2  749347  Find Love Or Die Trying      PS5  ['Sunseeker Games']
# 3  749341    Medieval Match Master      PS4       ['Erik Games']
# 4  749097           Bust A Block 2      PS5         ['ThiGames']
#
#             publishers            genres supported_languages release_date
# 0       ['Erik Games']        ['Puzzle']                 NaN   2024-11-22
# 1     ['GrizzlyGames']               NaN                 NaN   2024-11-21
# 2  ['Ratalaika Games']  ['Visual Novel']                 NaN   2024-11-22
# 3       ['Erik Games']        ['Puzzle']                 NaN   2024-11-22
# 4         ['ThiGames']        ['Puzzle']                 NaN   2024-11-21

# %%
history_playstation = pd.read_csv("playstation/history.csv")
history_playstation.head()
# Out:
#    playerid   achievementid        date_acquired
# 0   1911732  670209_5436079  2024-11-28 10:23:24
# 1   1911732  670209_5436078  2024-11-28 09:36:41
# 2   1911732  670209_5436077  2024-11-28 08:31:54
# 3   1911732  670209_5436076  2024-11-28 08:19:23
# 4   1911732  658551_5368954  2024-10-05 13:12:35

# %%
players_playstation = pd.read_csv("playstation/players.csv")
players_playstation.head()
# Out:
#    playerid         nickname             country
# 0   2744567  ieizazuBisnorog             Croatia
# 1    328452     DiscoGitaroo       United States
# 2   2521482          Ectivey      United Kingdom
# 3    390175      Tomie_Again  Korea, Republic of
# 4   4348945     Lordhell1986  Russian Federation

# %%
prices_playstation = pd.read_csv("playstation/prices.csv")
prices_playstation.head()
# Out:
#    gameid    usd    eur    gbp     jpy     rub date_acquired
# 0  749347  10.39  10.39   7.99  1408.0   929.0    2025-02-22
# 1  749281   1.49   1.49   1.19   220.0     NaN    2025-02-22
# 2  749839  14.99  14.99  11.99  2310.0  1069.0    2025-02-22
# 3  749280   1.49   1.49   1.19   220.0     NaN    2025-02-22
# 4  749375   0.99   0.49   0.39   165.0    71.0    2025-02-22

# %%
purchased_games_playstation = pd.read_csv("playstation/purchased_games.csv")
purchased_games_playstation.head()
# Out:
#    playerid                                            library
# 0    268071  [14972, 417905, 14693, 7742, 20162, 461983, 12...
# 1   2218485  [410618, 17456, 16034, 138931, 175202, 331007,...
# 2    253885  [417808, 706747, 619583, 492711, 555631, 18167...
# 3   1911732  [670209, 694794, 658551, 582894, 602666, 65531...
# 4   3098524  [19362, 170350, 12653, 20230, 12750, 18141, 41...

# %%
achievements_steam = pd.read_csv("steam/achievements.csv")
achievements_steam.head()
# Out:
#                    achievementid   gameid               title  \
# 0         2621440_ACH_FIRST_KILL  2621440          FIRST KILL
# 1  2621440_ACH_0_LEVEL_COMPLETED  2621440  TUTORIAL COMPLETED
# 2  2621440_ACH_1_LEVEL_COMPLETED  2621440         FIRST LEVEL
# 3  2621440_ACH_2_LEVEL_COMPLETED  2621440        SECOND LEVEL
# 4  2621440_ACH_3_LEVEL_COMPLETED  2621440         THIRD LEVEL
#
#                         description
# 0        You should kill ONE enemy.
# 1     You should complete tutorial.
# 2   You should complete first level
# 3  You should complete second level
# 4   You should complete third level

# %%
friends_steam = pd.read_csv("steam/friends.csv")
friends_steam.head()
# Out:
#             playerid                                            friends
# 0  76561198060422271  ['76561198018120276', '76561198034545417', '76...
# 1  76561198113439786  ['76561198047435192', '76561198059136488', '76...
# 2  76561198149851326  ['76561197991555589', '76561198003513187', '76...
# 3  76561198296997371                                                NaN
# 4  76561198895573082  ['76561197960300358', '76561197961330830', '76...

# %%
games_steam = pd.read_csv("steam/games.csv")
games_steam.head()
# Out:
#     gameid                                              title developers  \
# 0  3281560         Horror Game To Play With Friends! Playtest        NaN
# 1  3280930                            Eternals' Path Playtest        NaN
# 2  3280770  ANGST: A TALE OF SURVIVAL - Singleplayer Playtest        NaN
# 3  3279790                                   Montabi Playtest        NaN
# 4  3278320                                   파이팅걸 유리 Playtest        NaN
#
#   publishers genres supported_languages release_date
# 0        NaN    NaN                 NaN   2024-10-21
# 1        NaN    NaN                 NaN   2024-10-17
# 2        NaN    NaN                 NaN   2024-10-13
# 3        NaN    NaN                 NaN   2024-10-13
# 4        NaN    NaN                 NaN   2024-10-12

# %%
history_steam = pd.read_csv("steam/history.csv")
history_steam.head()
# Out:
#             playerid achievementid        date_acquired
# 0  76561198220441373  403640_ACH_1  2019-12-18 15:33:43
# 1  76561198220441373  403640_ACH_2  2019-12-18 23:49:51
# 2  76561198220441373  403640_ACH_3  2019-12-19 23:05:07
# 3  76561198220441373  403640_ACH_4  2019-12-24 05:50:49
# 4  76561198220441373  403640_ACH_5  2023-04-19 22:39:36

# %%
players_steam = pd.read_csv("steam/players.csv")
players_steam.head()
# Out:
#             playerid     country              created
# 0  76561198287452552      Brazil  2016-03-02 06:14:20
# 1  76561198040436563      Israel  2011-04-10 17:10:06
# 2  76561198049686270         NaN  2011-09-28 21:43:59
# 3  76561198155814250  Kazakhstan  2014-09-24 19:52:47
# 4  76561198119605821         NaN  2013-12-26 00:25:50

# %%
prices_steam = pd.read_csv("steam/prices.csv")
prices_steam.head()
# Out:
#     gameid  usd  eur  gbp  jpy  rub date_acquired
# 0  3281560  NaN  NaN  NaN  NaN  NaN    2024-11-28
# 1  3280930  NaN  NaN  NaN  NaN  NaN    2024-11-28
# 2  3280770  NaN  NaN  NaN  NaN  NaN    2024-11-28
# 3  3279790  NaN  NaN  NaN  NaN  NaN    2024-11-28
# 4  3278320  NaN  NaN  NaN  NaN  NaN    2024-11-28

# %%
purchased_games_steam = pd.read_csv("steam/purchased_games.csv")
purchased_games_steam.head()
# Out:
#             playerid                                            library
# 0  76561198060698936  [60, 1670, 3830, 1600, 2900, 2910, 2920, 4800,...
# 1  76561198287452552  [10, 80, 100, 240, 2990, 6880, 6910, 6920, 698...
# 2  76561198040436563  [10, 80, 100, 300, 20, 30, 40, 50, 60, 70, 130...
# 3  76561198042412488  [300, 240, 220, 320, 360, 4300, 4800, 4000, 61...
# 4  76561198119605821  [47870, 108600, 550, 271590, 331470, 381210, 2...

# %%
reviews = pd.read_csv("steam/reviews.csv")
reviews.head()
# Out:
#    reviewid           playerid  gameid  \
# 0    639543  76561198796340888     730
# 1    639544  76561198028706627  393380
# 2    639545  76561198028706627      10
# 3    639546  76561198049356580  469600
# 4    639547  76561198272817436     730
#
#                                               review  helpful  funny  awards  \
# 0  Goud gamę i have 3 vac ban acont but i stilll ...        0      0       0
# 1  ---{ Graphics }---☐ You forget what reality is...        0      0       0
# 2                       One of the best FPS games :)        0      0       0
# 3                  gayet güzel w3 havasını yakalıyor        0      0       0
# 4                    ONE OF THE GAMES I COME BACK TO        2      0       0
#
#        posted
# 0  2018-03-22
# 1  2025-01-03
# 2  2012-05-13
# 3  2018-04-21
# 4  2020-01-23

# %%
achievements_xbox = pd.read_csv("xbox/achievements.csv")
achievements_xbox.head()
# Out:
#     achievementid  gameid         title  \
# 0  751069_6114697  751069  Sweet Dreams
# 1  751069_6114698  751069    Lumberjack
# 2  751069_6114699  751069         Miner
# 3  751069_6114700  751069          Cook
# 4  751069_6114701  751069       Forager
#
#                                  description  points
# 0  Go to sleep and wake up feeling refreshed    50.0
# 1                       Chop your first tree    50.0
# 2                      Mine your first stone    50.0
# 3                       Cook your first meal    50.0
# 4                 Collect your first berries    50.0

# %%
games_xbox = pd.read_csv("xbox/games.csv")
games_xbox.head()
# Out:
#    gameid                title            developers            publishers  \
# 0    1253  Tomb Raider: Legend  ['crystal dynamics']  ['Crystal Dynamics']
# 1  749026                SANYA          ['helpnode']          ['Samustai']
# 2  747223            Sky Roll!           ['Entity3']           ['Entity3']
# 3  727440         Rogue Flight                   NaN                   NaN
# 4  750229           Infernitos        ['AFIL Games']        ['AFIL Games']
#
#                                               genres  \
# 0  ['Action', 'Adventure', 'strategy', 'Simulation']
# 1                     ['Adventure', 'Point & Click']
# 2                                     ['Platformer']
# 3                                                NaN
# 4                                         ['Puzzle']
#
#                           supported_languages release_date
# 0  ['French', 'Spanish', 'German', 'Italian']   2009-08-11
# 1                                         NaN   2024-11-22
# ...

# %%
history_xbox = pd.read_csv("xbox/history.csv")
history_xbox.head()
# Out:
#    playerid   achievementid        date_acquired
# 0   2466527  750641_6112019  2024-11-27 22:37:31
# 1   2466527  750641_6111985  2024-11-27 00:14:26
# 2   2466527  557191_4661215  2024-11-27 16:15:38
# 3   2466527  557191_4661196  2024-11-27 12:15:35
# 4   2466527  557191_4661203  2024-11-27 11:25:50

# %%
players_xbox = pd.read_csv("xbox/players.csv")
players_xbox.head()
# Out:
#    playerid         nickname
# 0    848738           smrnov
# 1    848736  RedmptionDenied
# 2   1470783          Healtti
# 3    848735        jimmyhova
# 4    848739       Stallion83

# %%
prices_xbox = pd.read_csv("xbox/prices.csv")
prices_xbox.head()
# Out:
#    gameid    usd    eur    gbp  jpy     rub date_acquired
# 0    1253  19.99  19.99  15.99  NaN  1772.0    2025-02-22
# 1  727440  17.99  17.99  14.99  NaN  1595.0    2025-02-22
# 2  747995   4.79   4.79   3.99  NaN   425.0    2025-02-22
# 3  727135  17.99  17.99  14.99  NaN  1595.0    2025-02-22
# 4  748541  19.99  19.99  16.74  NaN  1772.0    2025-02-22

# %%
purchased_games_xbox = pd.read_csv("xbox/purchased_games.csv")
purchased_games_xbox.head()
# Out:
#    playerid                                            library
# 0    848738  [14711, 2128, 10783, 9118, 7235, 9637, 717236,...
# 1    848736  [707376, 747223, 550303, 620354, 734202, 74678...
# 2   1470783  [638932, 32551, 748147, 468697, 446682, 615753...
# 3    848735  [736287, 555825, 717258, 422060, 12645, 550263...
# 4    848739  [698325, 443814, 745210, 747223, 734202, 71154...

# %% [markdown]
# #### Nettoyage du dataset achievement

# %%
#Ajout de la colonne plateforme aux dataset achivements
achievements_playstation['plateforme'] = 'playstation'
achievements_steam['plateforme'] = 'steam'
achievements_xbox['plateforme'] = 'xbox'

#concatenation des dataset achievement
achievements = pd.concat(objs = [achievements_playstation, achievements_steam, achievements_xbox], axis = 0, ignore_index=True)

#Ajout de unknown dans les lignes vides
achievements = achievements.fillna({'title': 'unknown', 'description': 'unknown', 'points':'Null'})

#l'identifiant de la colonne gameid est suffixé par la plateforme 
achievements['gameid'] = achievements['gameid'].astype('str') + '_' + achievements['plateforme']

# %%
achievements
# Out:
#           achievementid              gameid                 title  \
# 0        749980_6103480  749980_playstation          Platinum Cup
# 1        749980_6103481  749980_playstation       Arcade Beginner
# 2        749980_6103482  749980_playstation  Arcade Beginner Dirt
# 3        749980_6103483  749980_playstation   Arcade Intermediate
# 4        749980_6103484  749980_playstation       Arcade Advanced
# ...                 ...                 ...                   ...
# 3136696  333262_6158528         333262_xbox           Animal Farm
# 3136697  333262_6158529         333262_xbox           Wormageddon
# 3136698  333262_6158530         333262_xbox    That's No Asteroid
# 3136699  333262_6158531         333262_xbox      X Marks the Spot
# 3136700  333262_6158532         333262_xbox           Beastmaster
#
#                                                description    rarity  \
# 0                                     Get all the trophies  Platinum
# ...

# %% [markdown]
# #### Nettoyage des datasets games

# %%
#Ajout d'une colonne plateforme
games_playstation['plateforme'] = 'playstation'
games_steam['plateforme'] = 'steam'
games_xbox['plateforme'] = 'xbox'

#concatenation des dataset games
games = pd.concat(objs = [games_playstation, games_steam, games_xbox], axis = 0, ignore_index=True)

#remplacement des valeurs vides par unknown
games = games.fillna({'title': 'unknown', 'platform': 'unknown', 'developers' : 'unknown', 'publishers': 'unknown', 'genres': 'unknown', 'supported_languages': 'unknown'})

#Ajout d'une colonne contenant le genre principal
games['main_genre'] = games['genres'].str.strip('[]').str.replace("'", "").str.split(',').str[0]

#Conversion des colonnes publisher, developers et supported_languages en list
games['developers'] = games['developers'].str.strip('[]').str.replace("'", "").str.split(',')
games['publishers'] = games['publishers'].str.strip('[]').str.replace("'", "").str.split(',')
games['supported_languages'] = games['supported_languages'].str.strip('[]').str.replace("'", "").str.split(',')

#nombre de langue par jeu
games['supported_languages_count'] = games['supported_languages'].apply(len)

#reconversion de la colonne supported_languages en string afin d'affecter 0 à la colonne supported_languages_count où la colonne supported_languages vaut unknow
games['supported_languages'] = games['supported_languages'].astype('str')
games.loc[
    games['supported_languages'] == "['unknown']",
    'supported_languages_count'
] = 0

#conversion de la colonne supported_languages en liste
games['supported_languages'] = games['supported_languages'].str.strip('[]').str.replace("'", "").str.split(',')

#conversion de la date release_date en format date
games['release_date'] = pd.to_datetime(arg=games['release_date'])

#ajout d'une colonne année de sortie
games['release_year'] = games['release_date'].dt.year

#l'identifiant du jeu est suffixé par la plateforme
games['gameid'] = games['gameid'].astype('str') + '_' + games['plateforme']

# %%
games
# Out:
#                     gameid                                          title  \
# 0       749375_playstation                          Medieval Match Master
# 1       749839_playstation                        Sunforge Solar Survival
# 2       749347_playstation                        Find Love Or Die Trying
# 3       749341_playstation                          Medieval Match Master
# 4       749097_playstation                                 Bust A Block 2
# ...                    ...                                            ...
# 131883         163747_xbox                              Fishing Sim World
# 131884         163627_xbox  Construction Simulator 2 US - Console Edition
# 131885           6817_xbox                                 Saraiva Player
# 131886           6807_xbox                                     SKY ONLINE
# 131887           2519_xbox                           Crazy Machines Elem.
#
#        platform            developers         publishers  \
# ...

# %% [markdown]
# #### Nettoyage des dataset history

# %%
#Ajout d'une colonne plateforme
history_playstation['plateforme'] = 'playstation'
history_steam['plateforme'] = 'steam'
history_xbox['plateforme'] = 'xbox'

#concatenation des dataset history
history = pd.concat(objs = [history_playstation, history_steam, history_xbox], axis = 0, ignore_index=True)

#conversion de la date date_acquired en format date
history['date_acquired'] = pd.to_datetime(arg=history['date_acquired'])

#ajout d'une colonne année d'acquisition'
history['acquired_year'] = history['date_acquired'].dt.year

#l'identifiant du jeu est suffixé par la plateforme
history['playerid'] = history['playerid'].astype('str') + '_' + history['plateforme']

# %%
history
# Out:
#                      playerid   achievementid       date_acquired  \
# 0         1911732_playstation  670209_5436079 2024-11-28 10:23:24
# 1         1911732_playstation  670209_5436078 2024-11-28 09:36:41
# 2         1911732_playstation  670209_5436077 2024-11-28 08:31:54
# 3         1911732_playstation  670209_5436076 2024-11-28 08:19:23
# 4         1911732_playstation  658551_5368954 2024-10-05 13:12:35
# ...                       ...             ...                 ...
# 45479857          513481_xbox     2223_297052 2009-12-03 00:10:57
# 45479858          513481_xbox     2223_304919 2009-12-01 19:22:26
# 45479859          513481_xbox     2223_304920 2009-12-01 18:33:36
# 45479860          513481_xbox     2223_304921 2009-12-01 18:22:18
# 45479861          513481_xbox     2223_304922 2009-12-01 18:12:40
#
#            plateforme  acquired_year
# 0         playstation           2024
# 1         playstation           2024
# 2         playstation           2024
# ...

# %% [markdown]
# #### Nettoyage des dataset players

# %%
#Ajout d'une colonne plateforme
players_playstation['plateforme'] = 'playstation'
players_steam['plateforme'] = 'steam'
players_xbox['plateforme'] = 'xbox'

#Concaténation des dataset plateforme
players = pd.concat([players_playstation, players_steam, players_xbox], axis = 0, ignore_index= True)

#Suppression de la colonne nickname
players.drop('nickname', axis=1, inplace=True)

#Conversion de la colonne created au format date
players['created'] = pd.to_datetime(arg = players['created'],errors='coerce')

#Ajout de la colonne année de création
players['created_year'] = players['created'].dt.year

#remplacement des valeurs vide par unknown
players = players.fillna({'country': 'unknown', 'created': 'unknown', 'created_date' : 'unknown', 'created_time' : 'unknown'})

#l'identifiant playerid est suffixé par la plateforme
players['playerid'] = players['playerid'].astype('str') + '_' + players['plateforme']

# %%
players
# Out:
#                     playerid             country   plateforme  created  \
# 0        2744567_playstation             Croatia  playstation  unknown
# 1         328452_playstation       United States  playstation  unknown
# 2        2521482_playstation      United Kingdom  playstation  unknown
# 3         390175_playstation  Korea, Republic of  playstation  unknown
# 4        4348945_playstation  Russian Federation  playstation  unknown
# ...                      ...                 ...          ...      ...
# 1055728         1773447_xbox             unknown         xbox  unknown
# 1055729         1934243_xbox             unknown         xbox  unknown
# 1055730         2140366_xbox             unknown         xbox  unknown
# 1055731         2231830_xbox             unknown         xbox  unknown
# 1055732         2526457_xbox             unknown         xbox  unknown
#
#          created_year
# 0                 NaN
# 1                 NaN
# 2                 NaN
# ...

# %% [markdown]
# #### Nettoyage du dataset price

# %%
#Ajout d'une colonne plateforme
prices_playstation['plateforme'] = 'playstation'
prices_steam['plateforme'] = 'steam'
prices_xbox['plateforme'] = 'xbox'

#Concatenation des dataset price
prices = pd.concat([prices_playstation, prices_steam, prices_xbox], axis = 0, ignore_index= True)

#Conversion de la colonne date_acquired en date
prices['date_acquired'] = pd.to_datetime(arg = prices['date_acquired'],errors='coerce')

#Ajout de l'année du prix
prices['acquired_year'] =  prices['date_acquired'].dt.year

#L'identifiant du jeu est suffixé par la plateforme
prices['gameid'] = prices['gameid'].astype('str') + '_' + prices['plateforme']

# %%
prices
# Out:
#                      gameid    usd    eur    gbp     jpy     rub  \
# 0        749347_playstation  10.39  10.39   7.99  1408.0   929.0
# 1        749281_playstation   1.49   1.49   1.19   220.0     NaN
# 2        749839_playstation  14.99  14.99  11.99  2310.0  1069.0
# 3        749280_playstation   1.49   1.49   1.19   220.0     NaN
# 4        749375_playstation   0.99   0.49   0.39   165.0    71.0
# ...                     ...    ...    ...    ...     ...     ...
# 4499722         717371_xbox   4.99   4.99   4.19     NaN   443.0
# 4499723           3813_xbox    NaN    NaN    NaN     NaN     NaN
# 4499724           3878_xbox    NaN    NaN    NaN     NaN     NaN
# 4499725           2059_xbox  59.99  69.99  54.99     NaN  6218.0
# 4499726         185222_xbox    NaN    NaN    NaN     NaN     NaN
#
#         date_acquired   plateforme  acquired_year
# 0          2025-02-22  playstation           2025
# 1          2025-02-22  playstation           2025
# ...

# %% [markdown]
# #### Conversion des prix en dollar

# %%
# Remplacer les valeurs manquantes par Null

prices = prices.replace(np.nan, 'Null')

# Supprimer les gameid en double dans le dataframe prices

price_without_double = prices.drop_duplicates(subset='gameid')

# Copier le DataFrame original
prices_usd = price_without_double.copy()

# Remplacer 'Null' par np.nan
prices_usd = prices_usd.replace('Null', np.nan)

# Colonnes de devise
cols = ['usd', 'eur', 'gbp', 'jpy', 'rub']

# Convertir les colonnes en float
for col in cols:
    prices_usd[col] = prices_usd[col].astype(float)

# Taux de conversion vers USD
eur_to_usd = 1.08
gbp_to_usd = 1.26
jpy_to_usd = 0.0066
rub_to_usd = 0.011

# Conversion : on remplace les valeurs par leur équivalent en USD
prices_usd['eur'] = prices_usd['eur'] / eur_to_usd
prices_usd['gbp'] = prices_usd['gbp'] / gbp_to_usd
prices_usd['jpy'] = prices_usd['jpy'] * jpy_to_usd
prices_usd['rub'] = prices_usd['rub'] * rub_to_usd

# Ajouter la colonne 'genre principal' du df games à prices_usd

prices_usd = prices_usd.merge(games[['gameid', 'main_genre']], on='gameid', how='left')

# Vérification
prices_usd[['gameid', 'usd', 'eur', 'gbp', 'jpy', 'rub', 'date_acquired', 'plateforme', 'main_genre']].head()
# Out:
# C:\Users\ndiem\AppData\Local\Temp\ipykernel_1960\1747646993.py:13: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   prices_usd = prices_usd.replace('Null', np.nan)
#                gameid    usd        eur       gbp      jpy     rub  \
# 0  749347_playstation  10.39   9.620370  6.341270   9.2928  10.219
# 1  749281_playstation   1.49   1.379630  0.944444   1.4520     NaN
# 2  749839_playstation  14.99  13.879630  9.515873  15.2460  11.759
# 3  749280_playstation   1.49   1.379630  0.944444   1.4520     NaN
# 4  749375_playstation   0.99   0.453704  0.309524   1.0890   0.781
#
#   date_acquired   plateforme    main_genre
# 0    2025-02-22  playstation  Visual Novel
# 1    2025-02-22  playstation           NaN
# 2    2025-02-22  playstation       unknown
# ...

# %% [markdown]
# #### Nettoyage des dataset purchased_game

# %%
#Ajout de la colonne plateforme
purchased_games_playstation['plateforme'] = 'playstation'
purchased_games_steam['plateforme'] = 'steam'
purchased_games_xbox['plateforme'] = 'xbox'

#concaténation des dataset purchased_games
purchased_games = pd.concat([purchased_games_playstation, purchased_games_steam, purchased_games_xbox], axis = 0, ignore_index= True)

#identifiant du joueur suffixé par le plateforme
purchased_games['playerid'] = purchased_games['playerid'].astype('str') + '_' + purchased_games['plateforme']

#ajout d'une colonne contenant le nombre de jeu acheté par joueur
purchased_games['games_bought'] = purchased_games['library'].str.split(',').str.len()

#conversion de la colonne library en list
purchased_games['library'] = purchased_games['library'].str.strip('[]').str.replace("'", "").str.split(',')

# %%
purchased_games
# Out:
#                    playerid  \
# 0        268071_playstation
# 1       2218485_playstation
# 2        253885_playstation
# 3       1911732_playstation
# 4       3098524_playstation
# ...                     ...
# 195591          698172_xbox
# 195592          606933_xbox
# 195593          776695_xbox
# 195594         3069400_xbox
# 195595         4017053_xbox
#
#                                                   library   plateforme  \
# 0       [14972,  417905,  14693,  7742,  20162,  46198...  playstation
# 1       [410618,  17456,  16034,  138931,  175202,  33...  playstation
# 2       [417808,  706747,  619583,  492711,  555631,  ...  playstation
# 3       [670209,  694794,  658551,  582894,  602666,  ...  playstation
# 4       [19362,  170350,  12653,  20230,  12750,  1814...  playstation
# ...                                                   ...          ...
# 195591  [1225,  2937,  3597,  2114,  1142,  2152,  118...         xbox
# ...

# %%
purchased_games2 = purchased_games.groupby('plateforme').sum('games_bought').reset_index()
purchased_games2['rate'] = round(purchased_games2['games_bought'] / purchased_games['games_bought'].sum() * 100, 1)
purchased_games2
# Out:
#     plateforme  games_bought  rate
# 0  playstation    10893552.0  31.3
# 1        steam    11258715.0  32.3
# 2         xbox    12667877.0  36.4

# %%
round(0.363809 * 100)
# Out:
# 36

# %% [markdown]
# #### Nettoyage du dataset review

# %%
#Remplissage des valeurs vide par unknown
reviews = reviews.fillna({'review': 'unknown'})

#Ajout de _steam aux identifiants gameid et playerid
reviews['gameid'] = reviews['gameid'].astype('str') + '_steam'
reviews['playerid'] = reviews['playerid'].astype('str') + '_steam'

# Crée une nouvelle colonne avec le nombre d'avis par jeu dans le dataframe reviews
reviews['reviews_count'] = reviews['gameid'].map(reviews['gameid'].value_counts())

reviews
# Out:
#          reviewid                 playerid        gameid  \
# 0          639543  76561198796340888_steam     730_steam
# 1          639544  76561198028706627_steam  393380_steam
# 2          639545  76561198028706627_steam      10_steam
# 3          639546  76561198049356580_steam  469600_steam
# 4          639547  76561198272817436_steam     730_steam
# ...           ...                      ...           ...
# 1204529    639538  76561198400392792_steam     550_steam
# 1204530    639539  76561198375531601_steam  739630_steam
# 1204531    639540  76561198375531601_steam  945360_steam
# 1204532    639541  76561198199434213_steam  412220_steam
# 1204533    639542  76561198994605189_steam     570_steam
#
#                                                     review  helpful  funny  \
# 0        Goud gamę i have 3 vac ban acont but i stilll ...        0      0
# 1        ---{ Graphics }---☐ You forget what reality is...        0      0
# ...

# %%
# Créer un dataframe avec un classement des jeux les plus commentés

most_reviewed_games = reviews.groupby('gameid').size().reset_index(name='reviews_count').sort_values('reviews_count', ascending=False)
most_reviewed_games['sum_helpful'] = reviews.groupby('gameid')['helpful'].sum().reset_index(name='sum_helpful')['sum_helpful']
most_reviewed_games['sum_funny'] = reviews.groupby('gameid')['funny'].sum().reset_index(name='sum_funny')['sum_funny']
most_reviewed_games['sum_awards'] = reviews.groupby('gameid')['awards'].sum().reset_index(name='sum_awards')['sum_awards']

most_reviewed_games
# Out:
#               gameid  reviews_count  sum_helpful  sum_funny  sum_awards
# 45787      730_steam          70529        69629      27242       25922
# 41685      570_steam          15759        25678      10134        3827
# 41916   578080_steam          11743        36560      12855        4834
# 38189      440_steam          11409        25737       7910        3565
# 28978   271590_steam          10812        35052      11482        2865
# ...              ...            ...          ...        ...         ...
# 36790   394010_steam              1            6          0           0
# 18410  1968790_steam              1            4          0           0
# 18406  1968640_steam              1            6          0           0
# 51891   999030_steam              1            8          0           0
# 51886   998890_steam              1           37          0           0
#
# [51910 rows x 5 columns]

# %%
#Export des dataframe dans des fichiers csv
#achievements.to_csv('clean_data/achievements.csv')
#games.to_csv('clean_data/games.csv')
#history.to_csv('clean_data/history.csv')
#players.to_csv('clean_data/players.csv')
#prices.to_csv('clean_data/prices.csv')
#purchased_games.to_csv('clean_data/purchased_games.csv')
#reviews.to_csv('clean_data/reviews.csv')
#prices_usd.to_csv('clean_data/prices_usd.csv')

# %% [markdown]
# #### Succès économique

# %% [markdown]
# ##### Nombre d’exemplaires de jeux vendus par année ? par plateforme ? par genre ? Quelle est la corrélation entre le prix et le nombre de ventes ?

# %%
#Explode pour récupérer chaque jeu qu'un joueur a acheté
purchased_games_explode_library = purchased_games.explode('library')
purchased_games_explode_library.rename(columns=
    {
        'library':'gameid'
    },
    inplace=True
)

#ajout du suffixe de la plateforme dans l'identifiant du jeu
purchased_games_explode_library['gameid'] = purchased_games_explode_library['gameid'].astype('str') + '_' + purchased_games_explode_library['plateforme']
purchased_games_explode_library
# Out:
#                   playerid               gameid   plateforme  games_bought
# 0       268071_playstation    14972_playstation  playstation         231.0
# 0       268071_playstation   417905_playstation  playstation         231.0
# 0       268071_playstation    14693_playstation  playstation         231.0
# 0       268071_playstation     7742_playstation  playstation         231.0
# 0       268071_playstation    20162_playstation  playstation         231.0
# ...                    ...                  ...          ...           ...
# 195595        4017053_xbox            2526_xbox         xbox          56.0
# 195595        4017053_xbox            6889_xbox         xbox          56.0
# 195595        4017053_xbox            1128_xbox         xbox          56.0
# 195595        4017053_xbox            1155_xbox         xbox          56.0
# 195595        4017053_xbox            1141_xbox         xbox          56.0
#
# [34875751 rows x 4 columns]

# %%
purchased_games_explode_library.sort_values(by='games_bought', ascending=False)
# Out:
#                        playerid          gameid plateforme  games_bought
# 47485   76561198094227663_steam   3327150_steam      steam       32463.0
# 47485   76561198094227663_steam   3217320_steam      steam       32463.0
# 47485   76561198094227663_steam   2931920_steam      steam       32463.0
# 47485   76561198094227663_steam   2933180_steam      steam       32463.0
# 47485   76561198094227663_steam   3068700_steam      steam       32463.0
# ...                         ...             ...        ...           ...
# 149123  76561198129685119_steam       nan_steam      steam           NaN
# 149125  76561199063275634_steam       nan_steam      steam           NaN
# 149127  76561198944668572_steam       nan_steam      steam           NaN
# 149128  76561198033563710_steam       nan_steam      steam           NaN
# 149129  76561198165611843_steam       nan_steam      steam           NaN
#
# [34875751 rows x 4 columns]

# %%
#jointure des prix, des jeux et des jeux achetés
purchased_games_price_join = pd.merge(left=prices_usd[['gameid','usd','date_acquired']], right=purchased_games_explode_library, on='gameid', how='inner')
purchased_games_price_join = pd.merge(left = games[['gameid','title','main_genre']], right = purchased_games_price_join, on ='gameid', how='inner')

#Ajout de l'année du prix
purchased_games_price_join['year_acquired'] = purchased_games_price_join['date_acquired'].dt.year

purchased_games_price_join
# Out:
#                     gameid                              title  \
# 0       746067_playstation            LEGO Horizon Adventures
# 1       746067_playstation            LEGO Horizon Adventures
# 2       746067_playstation            LEGO Horizon Adventures
# 3       746067_playstation            LEGO Horizon Adventures
# 4       746067_playstation            LEGO Horizon Adventures
# ...                    ...                                ...
# 119435         459209_xbox                          eFootball
# 119436         390740_xbox                         Moving Out
# 119437         337356_xbox  Farming Simulator 17 - Windows 10
# 119438         168046_xbox                     Carnival Games
# 119439         163747_xbox                  Fishing Sim World
#
#               main_genre    usd date_acquired            playerid  \
# 0       Action-Adventure  59.99    2025-02-22  298261_playstation
# 1       Action-Adventure  59.99    2025-02-22   14298_playstation
# ...

# %% [markdown]
#         La jointure se fait avec des inner join car certains jeux acheté ne  sont ni présents dans la table games ni dans la table price
#         On ne garde que la devise usd pour les prix car les prix dans les autres devise ne correpondent pas aux taux de conversion de la date d'achat du jeu

# %%
#nombre total de ventes
nb_total_vente = purchased_games_price_join.shape[0]

#nombre de ventes par plateforme
nb_sale_by_plateforme = purchased_games_price_join.groupby(['plateforme']).size().reset_index(name='nb_sale').sort_values(by='nb_sale', ascending=False)

nb_sale_by_plateforme['rate_sale'] = nb_sale_by_plateforme['nb_sale'] / nb_total_vente
nb_sale_by_plateforme
# Out:
#     plateforme  nb_sale  rate_sale
# 1        steam    42249   0.353726
# 2         xbox    39458   0.330358
# 0  playstation    37733   0.315916

# %%
#nombre de ventes par genre
nb_sale_by_main_genre = purchased_games_price_join.groupby(['main_genre']).size().reset_index(name='nb_sale').sort_values(by='nb_sale', ascending=False)

nb_sale_by_main_genre['rate_sale'] = nb_sale_by_main_genre['nb_sale'] / nb_total_vente

nb_sale_by_main_genre.head(50)
# Out:
#                   main_genre  nb_sale  rate_sale
# 3                     Action    42606   0.356715
# 68                    Sports     7817   0.065447
# 32              Free to Play     6561   0.054931
# 83                   shooter     5085   0.042574
# 29      First Person Shooter     4647   0.038907
# 7                  Adventure     4563   0.038203
# 51                Open World     3919   0.032811
# 6                 Action-RPG     3610   0.030224
# 17                    Casual     3498   0.029287
# 73      Third Person Shooter     3375   0.028257
# 38                     Indie     2777   0.023250
# 65                Simulation     2164   0.018118
# 57                       RPG     2013   0.016854
# 5           Action-Adventure     2011   0.016837
# 85                    sports     1944   0.016276
# 60              Role Playing     1731   0.014493
# 58                    Racing     1616   0.013530
# 70                  Strategy     1532   0.012827
# ...

# %%
#nombre de ventes par genre et par plateforme

nb_sale_by_main_genre_plateforme = purchased_games_price_join.groupby(['main_genre', 'plateforme']).size().reset_index(name='nb_sale').sort_values(by='nb_sale', ascending=False)

nb_sale_by_main_genre_plateforme['rate_sale'] = nb_sale_by_main_genre_plateforme['nb_sale'] / nb_total_vente
nb_sale_by_main_genre_plateforme.head(50)
# Out:
#                    main_genre   plateforme  nb_sale  rate_sale
# 6                      Action        steam    32170   0.269340
# 7                      Action         xbox     7453   0.062400
# 57               Free to Play  playstation     6535   0.054714
# 122                    Sports  playstation     4660   0.039015
# 54       First Person Shooter         xbox     3821   0.031991
# 88                 Open World  playstation     3784   0.031681
# 153                   shooter         xbox     3612   0.030241
# 33                     Casual        steam     3446   0.028851
# 124                    Sports         xbox     3139   0.026281
# 5                      Action  playstation     2983   0.024975
# 135      Third Person Shooter         xbox     2777   0.023250
# 14                  Adventure  playstation     2113   0.017691
# 13                 Action-RPG         xbox     1942   0.016259
# 67                      Indie        steam     1673   0.014007
# ...

# %%
#nombre de ventes par genre sur playsation

purchased_games_price_join_playstation = purchased_games_price_join[purchased_games_price_join['plateforme'] == 'playstation']

nb_total_vente_playstation = purchased_games_price_join_playstation.shape[0]

nb_sale_by_main_genre_playstation = purchased_games_price_join_playstation.groupby(['main_genre']).size().reset_index(name='nb_sale').sort_values(by='nb_sale', ascending=False)

nb_sale_by_main_genre_playstation['rate_sale'] = nb_sale_by_main_genre_playstation['nb_sale'] / nb_total_vente_playstation

nb_sale_by_main_genre_playstation.head(50)
# Out:
#                   main_genre  nb_sale  rate_sale
# 25              Free to Play     6535   0.173191
# 54                    Sports     4660   0.123499
# 39                Open World     3784   0.100284
# 3                     Action     2983   0.079055
# 7                  Adventure     2113   0.055999
# 6                 Action-RPG     1668   0.044205
# 67                   shooter     1473   0.039037
# 10                Automobile     1208   0.032014
# 4              Action Horror     1100   0.029152
# 5           Action-Adventure     1076   0.028516
# 48              Role Playing      947   0.025097
# 45                       RPG      911   0.024143
# 23      First Person Shooter      826   0.021891
# 22                  Fighting      780   0.020672
# 69                    sports      705   0.018684
# 30                     Indie      683   0.018101
# 59      Third Person Shooter      598   0.015848
# 11             Battle Royale      596   0.015795
# ...

# %%
#nombre de ventes par genre sur steam

purchased_games_price_join_steam = purchased_games_price_join[purchased_games_price_join['plateforme'] == 'steam']

nb_total_vente_steam = purchased_games_price_join_steam.shape[0]

nb_sale_by_main_genre_steam = purchased_games_price_join_steam.groupby(['main_genre']).size().reset_index(name='nb_sale').sort_values(by='nb_sale', ascending=False)

nb_sale_by_main_genre_steam['rate_sale'] = nb_sale_by_main_genre_steam['nb_sale'] / nb_total_vente_steam

nb_sale_by_main_genre_steam.head(50)
# Out:
#                main_genre  nb_sale  rate_sale
# 0                  Action    32170   0.761438
# 4                  Casual     3446   0.081564
# 10                  Indie     1673   0.039599
# 1               Adventure     1388   0.032853
# 19               Strategy     1215   0.028758
# 13                    RPG      717   0.016971
# 14                 Racing      694   0.016426
# 16             Simulation      401   0.009491
# 11  Massively Multiplayer      189   0.004473
# 8            Free To Play      155   0.003669
# 2    Animation & Modeling       53   0.001254
# 12                 Nudity       31   0.000734
# 20              Utilities       29   0.000686
# 3        Audio Production       20   0.000473
# 18                 Sports       18   0.000426
# 22                unknown       18   0.000426
# 21                Violent       17   0.000402
# 15         Sexual Content        4   0.000095
# 6            Early Access        4   0.000095
# ...

# %%
#nombre de ventes par genre sur xbox

purchased_games_price_join_xbox = purchased_games_price_join[purchased_games_price_join['plateforme'] == 'xbox']

nb_total_vente_xbox = purchased_games_price_join_xbox.shape[0]

nb_sale_by_main_genre_xbox = purchased_games_price_join_xbox.groupby(['main_genre']).size().reset_index(name='nb_sale').sort_values(by='nb_sale', ascending=False)

nb_sale_by_main_genre_xbox['rate_sale'] = nb_sale_by_main_genre_xbox['nb_sale'] / nb_total_vente_xbox

nb_sale_by_main_genre_xbox.head(50)
# Out:
#                           main_genre  nb_sale  rate_sale
# 2                             Action     7453   0.188884
# 22              First Person Shooter     3821   0.096837
# 63                           shooter     3612   0.091540
# 50                            Sports     3139   0.079553
# 55              Third Person Shooter     2777   0.070379
# 5                         Action-RPG     1942   0.049217
# 49                 Simulation Racing     1366   0.034619
# 65                            sports     1239   0.031400
# 48                        Simulation     1226   0.031071
# 6                          Adventure     1062   0.026915
# 53                          Survival     1041   0.026382
# 67                           unknown     1000   0.025343
# 4                   Action-Adventure      935   0.023696
# 45          Role-Playing Games (RPG)      826   0.020934
# 44                      Role Playing      784   0.019869
# ...

# %%
#Nombre de vente par année
nb_sale_by_year = purchased_games_price_join.groupby(['year_acquired']).size().reset_index(name='nb_sale').sort_values(by='nb_sale', ascending=False)
nb_sale_by_year
# Out:
#    year_acquired  nb_sale
# 1           2025    77200
# 0           2024    42240

# %%
#correlation entre le nombre de vente et le prix
sales_and_prices = purchased_games_price_join.groupby(['gameid','usd']).size().reset_index(name='nb_sale').sort_values(by='nb_sale', ascending=False)

sales_and_prices['rate_sale'] = sales_and_prices['nb_sale'] / nb_total_vente
sales_and_prices.sort_values(by='rate_sale', ascending=False)

sales_and_prices.head(50)
# Out:
#                   gameid     usd  nb_sale  rate_sale
# 185             10_steam    1.99    10577   0.088555
# 3316          4000_steam    5.99     2358   0.019742
# 4825           550_steam    1.99     1938   0.016226
# 1945        227300_steam    4.99      939   0.007862
# 6656    7779_playstation   19.79      919   0.007694
# 6998           9637_xbox   19.99      870   0.007284
# 6231            70_steam    1.99      850   0.007117
# 6553           7545_xbox   39.99      828   0.006932
# 2081           240_steam    1.99      712   0.005961
# 6084         693001_xbox  109.99      702   0.005877
# 1757            20_steam    1.24      560   0.004689
# 6562         755120_xbox   69.99      514   0.004303
# 92          105600_steam    4.99      468   0.003918
# 1512          19170_xbox   19.99      448   0.003751
# 1880           220_steam    1.99      444   0.003717
# 1160  167482_playstation   59.99      400   0.003349
# 6650           7756_xbox   39.99      393   0.003290
# ...

# %%
#nombre de ventes par genre et par année

nb_sale_by_main_genre_year = purchased_games_price_join.groupby(['main_genre']).size().reset_index(name='nb_sale').sort_values(by='nb_sale', ascending=False)

nb_sale_by_main_genre_year['rate_sale'] = nb_sale_by_main_genre_plateforme['nb_sale'] / nb_total_vente
nb_sale_by_main_genre_year.head(50)
# Out:
#                   main_genre  nb_sale  rate_sale
# 3                     Action    42606   0.000234
# 68                    Sports     7817   0.003525
# 32              Free to Play     6561   0.000218
# 83                   shooter     5085   0.000159
# 29      First Person Shooter     4647   0.000193
# 7                  Adventure     4563   0.062400
# 51                Open World     3919   0.006530
# 6                 Action-RPG     3610   0.269340
# 17                    Casual     3498   0.000159
# 73      Third Person Shooter     3375   0.000628
# 38                     Indie     2777   0.000226
# 65                Simulation     2164   0.000050
# 57                       RPG     2013   0.054714
# 5           Action-Adventure     2011   0.024975
# 85                    sports     1944   0.000251
# 60              Role Playing     1731   0.000050
# 58                    Racing     1616   0.000218
# 70                  Strategy     1532   0.000251
# ...

# %%
#Fichiers de sortie
nb_sale_by_plateforme.to_csv('out/nb_sale/nb_sale_by_plateforme.csv', index=False)
nb_sale_by_main_genre.to_csv('out/nb_sale/nb_sale_by_main_genre.csv', index=False)
nb_sale_by_main_genre_plateforme.to_csv('out/nb_sale/nb_sale_by_main_genre_plateforme.csv', index=False)
nb_sale_by_main_genre_playstation.to_csv('out/nb_sale/nb_sale_by_main_genre_playstation.csv', index=False)
nb_sale_by_main_genre_steam.to_csv('out/nb_sale/nb_sale_by_main_genre_steam.csv', index=False)
nb_sale_by_main_genre_xbox.to_csv('out/nb_sale/nb_sale_by_main_genre_xbox.csv', index=False)
nb_sale_by_year.to_csv('out/nb_sale/nb_sale_by_year.csv', index=False)
sales_and_prices.to_csv('out/nb_sale/sales_and_prices.csv', index=False)
nb_sale_by_main_genre_year.to_csv('out/nb_sale/nb_sale_by_main_genre_year.csv', index=False)

# %% [markdown]
# #### Top 10 des meilleurs développeur et publishers (+ chiffre d’affaires)

# %%
#jointure entre la dataframe jeu, prix et purchased_game
purchased_games_developers_publishers = pd.merge(left=prices_usd[['gameid','usd','date_acquired']], right=purchased_games_explode_library[['gameid','playerid']], on='gameid', how='inner')
purchased_games_developers_publishers = pd.merge(left = games[['gameid','developers','publishers','plateforme']], right = purchased_games_developers_publishers, on ='gameid', how='inner')
purchased_games_developers_publishers = pd.merge(left = players[['playerid','country']], right = purchased_games_developers_publishers, on ='playerid', how='inner')

purchased_games_developers_publishers
# Out:
#                    playerid             country              gameid  \
# 0       4348945_playstation  Russian Federation  707721_playstation
# 1        330548_playstation      United Kingdom  626776_playstation
# 2        327659_playstation       United States  628148_playstation
# 3        326586_playstation       United States  756264_playstation
# 4        328280_playstation             Germany      38_playstation
# ...                     ...                 ...                 ...
# 119435          487597_xbox             unknown           2055_xbox
# 119436          488844_xbox             unknown           8901_xbox
# 119437         1254579_xbox             unknown          16628_xbox
# 119438         1934243_xbox             unknown          13420_xbox
# 119439         2140366_xbox             unknown           2528_xbox
#
#                              developers                       publishers  \
# 0       [Deep Silver Dambuster Studios]                    [Deep Silver]
# ...

# %%
#conversion de la colonne prix en décimal
purchased_games_developers_publishers['usd'] = pd.to_numeric(purchased_games_developers_publishers['usd'],errors='coerce').astype('float64')

#Conversion de la colonne developer en string afin de pouvoir faire un group by
purchased_games_developers_publishers['developers'] = purchased_games_developers_publishers['developers'].astype('str')

total_revenue = purchased_games_developers_publishers['usd'].sum()

#Top 10 en CA des developers
best_developer = purchased_games_developers_publishers.groupby(['developers', 'plateforme', 'country'])['usd'].sum().reset_index(name='revenue').sort_values(by='revenue', ascending=False)

best_developer['rate_revenue'] = best_developer['revenue'] / total_revenue

best_developer
# Out:
#                 developers   plateforme   country   revenue  rate_revenue
# 6413    ['GSC Game World']         xbox   unknown  77292.94      0.046831
# 9491      ['MachineGames']         xbox   unknown  36014.84      0.021821
# 269     ['343 industries']         xbox   unknown  35150.70      0.021297
# 19537          ['unknown']         xbox   unknown  34068.62      0.020642
# 19281   ['rockstar north']         xbox   unknown  31950.96      0.019359
# ...                    ...          ...       ...       ...           ...
# 7927   ['Infinity Plus 2']  playstation    Brazil      0.00      0.000000
# 7926   ['Infinity Plus 2']  playstation   Austria      0.00      0.000000
# 7940   ['Infinity Plus 2']         xbox   unknown      0.00      0.000000
# 7939   ['Infinity Plus 2']        steam   unknown      0.00      0.000000
# 4597           ['Duhndal']        steam  Viet Nam      0.00      0.000000
#
# [19599 rows x 5 columns]

# %%
#Conversion de la colonne publishers en string afin de pouvoir faire un group by
purchased_games_developers_publishers['publishers'] = purchased_games_developers_publishers['publishers'].astype('str')

#Top 10 en CA des publishers
best_publishers = purchased_games_developers_publishers.groupby(['publishers', 'plateforme', 'country'])['usd'].sum().reset_index(name='revenue').sort_values(by='revenue', ascending=False)

best_publishers['rate_revenue'] = best_publishers['revenue'] / total_revenue
best_publishers
# Out:
#                   publishers plateforme  country   revenue  rate_revenue
# 7073   ['Microsoft Studios']       xbox  unknown  78232.83      0.047401
# 4814      ['GSC Game World']       xbox  unknown  77292.94      0.046831
# 1617  ['Bethesda Softworks']       xbox  unknown  74849.82      0.045351
# 9288      ['Rockstar Games']       xbox  unknown  54375.93      0.032946
# 3907     ['Electronic Arts']       xbox  unknown  51645.05      0.031291
# ...                      ...        ...      ...       ...           ...
# 8743         ['Raptor Byte']      steam  Germany      0.00      0.000000
# 8744         ['Raptor Byte']      steam    Japan      0.00      0.000000
# 8745         ['Raptor Byte']      steam  unknown      0.00      0.000000
# 6         [' RockGame S.A.']      steam  unknown      0.00      0.000000
# 5     [' HypeTrain Digital']      steam   Brazil      0.00      0.000000
#
# [13846 rows x 5 columns]

# %%
#Fichiers de sortie
best_developer.to_csv('out/best_publisher_and_developer/best_developer_country.csv', index=False)
best_publishers.to_csv('out/best_publisher_and_developer/best_publishers_country.csv', index=False)

# %%
#Chiffre d'affaire par plateforme
revenue_by_plateforme = purchased_games_developers_publishers.groupby(['plateforme'])['usd'].sum().reset_index(name='revenue').sort_values(by='revenue', ascending=False)
revenue_by_plateforme.to_csv('out/best_publisher_and_developer/revenue_by_plateforme.csv', index=False)
revenue_by_plateforme
# Out:
#     plateforme    revenue
# 2         xbox  772148.57
# 0  playstation  744970.65
# 1        steam  133343.47

# %% [markdown]
# ##### Nombre de joueur par genre

# %%
nb_players_by_genre = pd.merge(left=games[['gameid', 'main_genre']], right=purchased_games_explode_library, on='gameid', how='inner')
nb_players_by_genre = nb_players_by_genre.drop_duplicates(subset=['playerid','main_genre'])
nb_players_by_genre = nb_players_by_genre.groupby(['main_genre']).size().reset_index(name='nb_genre_by_player')
nb_players_by_genre.sort_values(by='nb_genre_by_player', ascending=False).head(50)
# Out:
#                   main_genre  nb_genre_by_player
# 3                     Action               42606
# 68                    Sports                7817
# 32              Free to Play                6561
# 83                   shooter                5085
# 29      First Person Shooter                4647
# 7                  Adventure                4563
# 51                Open World                3919
# 6                 Action-RPG                3610
# 17                    Casual                3498
# 73      Third Person Shooter                3375
# 38                     Indie                2777
# 65                Simulation                2164
# 57                       RPG                2013
# 5           Action-Adventure                2011
# 85                    sports                1944
# 60              Role Playing                1731
# 58                    Racing                1616
# 70                  Strategy                1532
# ...

# %%
#Fichiers de sortie
nb_players_by_genre.to_csv('out/nb_sale/nb_players_by_genre.csv', index=False)

# %% [markdown]
# #### Succès d'adoption

# %% [markdown]
# #### Quel est le taux d’achievements par jeux ? par joueur ? par année ? par période ?

# %%
#Nombre d'achievement par plateforme
achievements_by_plateforme = achievements.groupby('plateforme').size().reset_index(name='nb_achivement_by_plateforme')
achievements_by_plateforme
# Out:
#     plateforme  nb_achivement_by_plateforme
# 0  playstation                       846563
# 1        steam                      1939027
# 2         xbox                       351111

# %%
#jointure des dataset achivevement, game et history

achievements_main_columns = achievements[['achievementid','gameid','plateforme']]
history_main_columns = history[['playerid','achievementid','date_acquired', 'acquired_year']]
games_main_columns = games[['gameid', 'title']]

history_achievement_merge = pd.merge(left=achievements_main_columns, right=history_main_columns, on='achievementid', how='left')
history_achievement_game_merge = pd.merge(left=history_achievement_merge, right=games_main_columns, on='gameid', how='left')

#Remplacement des valeurs vide de la colonne title par unknown
history_achievement_game_merge.fillna(value={'title':'unknown'}, inplace=True)

history_achievement_game_merge.head(50)
# Out:
#      achievementid              gameid   plateforme             playerid  \
# 0   749980_6103480  749980_playstation  playstation                  NaN
# 1   749980_6103481  749980_playstation  playstation                  NaN
# 2   749980_6103482  749980_playstation  playstation                  NaN
# 3   749980_6103483  749980_playstation  playstation                  NaN
# 4   749980_6103484  749980_playstation  playstation                  NaN
# 5   749980_6103485  749980_playstation  playstation                  NaN
# 6   749980_6103486  749980_playstation  playstation                  NaN
# 7   749980_6103487  749980_playstation  playstation                  NaN
# 8   749980_6103488  749980_playstation  playstation                  NaN
# 9   749980_6103489  749980_playstation  playstation                  NaN
# 10  749980_6103490  749980_playstation  playstation                  NaN
# 11  749980_6103491  749980_playstation  playstation                  NaN
# ...

# %% [markdown]
#         Les lignes contenant les des valeurs playerid, date_acquired et acquired_year à vide correspondent à des achievement non atteints par les joueurs
#         Les valeurs title qui sont vides correpondent à des jeux qui sont dans la table achivement mais qui ne sont pas dans la table game

# %% [markdown]
# ##### Taux d'achivement terminé

# %%
#Récupération des achievement terminés
achievement_finish = history_achievement_game_merge[history_achievement_game_merge['playerid'].notnull()]
achievement_finish
# Out:
#            achievementid              gameid   plateforme  \
# 35        749909_6103322  749909_playstation  playstation
# 36        749909_6103322  749909_playstation  playstation
# 37        749909_6103323  749909_playstation  playstation
# 38        749909_6103323  749909_playstation  playstation
# 39        749909_6103324  749909_playstation  playstation
# ...                  ...                 ...          ...
# 46830990  753408_6165623         753408_xbox         xbox
# 46830991  753408_6165624         753408_xbox         xbox
# 46830992  753408_6165625         753408_xbox         xbox
# 46830993  753408_6165626         753408_xbox         xbox
# 46831020   18709_6138513          18709_xbox         xbox
#
#                      playerid       date_acquired  acquired_year  \
# 35         312151_playstation 2024-11-24 06:47:45         2024.0
# 36        4482527_playstation 2024-11-30 07:09:59         2024.0
# 37         312151_playstation 2024-12-13 03:39:07         2024.0
# ...

# %%
nb_achievement_finished_by_id = achievement_finish.groupby('achievementid').size().reset_index(name='nb_achivement_finished')

history_achievement_game_merge = pd.merge(left=history_achievement_game_merge, right=nb_achievement_finished_by_id, on='achievementid', how='left')
history_achievement_game_merge
# Out:
#            achievementid              gameid   plateforme playerid  \
# 0         749980_6103480  749980_playstation  playstation      NaN
# 1         749980_6103481  749980_playstation  playstation      NaN
# 2         749980_6103482  749980_playstation  playstation      NaN
# 3         749980_6103483  749980_playstation  playstation      NaN
# 4         749980_6103484  749980_playstation  playstation      NaN
# ...                  ...                 ...          ...      ...
# 46834593  333262_6158528         333262_xbox         xbox      NaN
# 46834594  333262_6158529         333262_xbox         xbox      NaN
# 46834595  333262_6158530         333262_xbox         xbox      NaN
# 46834596  333262_6158531         333262_xbox         xbox      NaN
# 46834597  333262_6158532         333262_xbox         xbox      NaN
#
#          date_acquired  acquired_year                  title  \
# 0                  NaT            NaN  Power Racing Bundle 2
# ...

# %%
history_achievement_game_merge['nb_achivement_finished'] = history_achievement_game_merge['nb_achivement_finished'].replace(np.nan,  0)
history_achievement_game_merge
# Out:
#            achievementid              gameid   plateforme playerid  \
# 0         749980_6103480  749980_playstation  playstation      NaN
# 1         749980_6103481  749980_playstation  playstation      NaN
# 2         749980_6103482  749980_playstation  playstation      NaN
# 3         749980_6103483  749980_playstation  playstation      NaN
# 4         749980_6103484  749980_playstation  playstation      NaN
# ...                  ...                 ...          ...      ...
# 46834593  333262_6158528         333262_xbox         xbox      NaN
# 46834594  333262_6158529         333262_xbox         xbox      NaN
# 46834595  333262_6158530         333262_xbox         xbox      NaN
# 46834596  333262_6158531         333262_xbox         xbox      NaN
# 46834597  333262_6158532         333262_xbox         xbox      NaN
#
#          date_acquired  acquired_year                  title  \
# 0                  NaT            NaN  Power Racing Bundle 2
# ...

# %%
#Taux des achivement terminé
finish_achivement_rate = achievement_finish.shape[0] / history_achievement_game_merge.shape[0]
finish_achivement_rate = pd.Series(finish_achivement_rate).reset_index(name='finish_achivement_rate')[['finish_achivement_rate']]

finish_achivement_rate
# Out:
#    finish_achivement_rate
# 0                0.971074

# %% [markdown]
# ##### Taux d'achivement terminé par plateforme

# %%
#Taux d'achievement terminé par plateforme
taux_achievement_by_plateforme = history_achievement_game_merge.groupby('plateforme')['nb_achivement_finished'].sum().reset_index()
taux_achievement_by_plateforme = pd.merge(left=taux_achievement_by_plateforme, right=achievements_by_plateforme, on='plateforme', how='inner')
taux_achievement_by_plateforme['ratio_nb_achiv_finish_and_nb_total_achiv'] = taux_achievement_by_plateforme['nb_achivement_finished'] / taux_achievement_by_plateforme['nb_achivement_by_plateforme']
taux_achievement_by_plateforme
# Out:
#     plateforme  nb_achivement_finished  nb_achivement_by_plateforme  \
# 0  playstation            7.442591e+09                       846563
# 1        steam            1.201810e+09                      1939027
# 2         xbox            4.923138e+09                       351111
#
#    ratio_nb_achiv_finish_and_nb_total_achiv
# 0                               8791.537770
# 1                                619.800474
# 2                              14021.598600

# %% [markdown]
# ##### Taux d'achivement terminé par jeu

# %%
nb_total_achievements_by_game = history_achievement_game_merge.groupby(['gameid', 'title', 'plateforme']).size().reset_index(name = 'nb_achievement_total_by_game')

nb_achievements_finished_by_game = achievement_finish.groupby(['gameid', 'title', 'plateforme']).size().reset_index(name = 'nb_achievement_finish')

#taux_achievement_by_game = pd.merge(left=nb_total_achievements_by_game, right=nb_achievements_finished_by_game, on=['gameid','title', 'plateforme'], how='left')

#taux_achievement_by_game['rate_finished_achivement'] = taux_achievement_by_game['nb_achievement_finish'] / taux_achievement_by_game['nb_achievement_total_by_game'] 

#taux_achievement_by_game.sort_values(by='rate_finished_achivement', ascending=False).head(50)

nb_achievements_finished_by_game
# Out:
#                  gameid                        title   plateforme  \
# 0         1000010_steam                  Crown Trick        steam
# 1         1000030_steam  Cook, Serve, Delicious! 3?!        steam
# 2         1000080_steam                      Zengeon        steam
# 3         1000360_steam                Hellish Quart        steam
# 4         1000410_steam          WRATH: Aeon of Ruin        steam
# ...                 ...                          ...          ...
# 46948  9998_playstation        Onechanbara Z2: Chaos  playstation
# 46949  9999_playstation               Lost Dimension  playstation
# 46950   999_playstation                      unknown  playstation
# 46951    99_playstation               Buzz!: Quiz TV  playstation
# 46952     9_playstation            SUPER STARDUST HD  playstation
#
#        nb_achievement_finish
# 0                        283
# 1                         11
# 2                          4
# 3                         12
# ...

# %% [markdown]
# ##### Taux d'achivement terminé par joueur

# %%
rate_achivement_by_player = achievement_finish['playerid'].nunique() / players.shape[0]
rate_achivement_by_player = pd.Series(rate_achivement_by_player).reset_index(name='rate_achivement_by_player')[['rate_achivement_by_player']]

rate_achivement_by_player
# Out:
#    rate_achivement_by_player
# 0                    0.01404

# %%
#Taux d'achievement terminé par plateforme
taux_achievement_by_plateforme = history_achievement_game_merge.groupby('plateforme')['nb_achivement_finished'].sum().reset_index()
taux_achievement_by_plateforme = pd.merge(left=taux_achievement_by_plateforme, right=achievements_by_plateforme, on='plateforme', how='inner')
taux_achievement_by_plateforme['ratio_nb_achiv_finish_and_nb_total_achiv'] = taux_achievement_by_plateforme['nb_achivement_finished'] / taux_achievement_by_plateforme['nb_achivement_by_plateforme']
taux_achievement_by_plateforme
# Out:
#     plateforme  nb_achivement_finished  nb_achivement_by_plateforme  \
# 0  playstation            7.442591e+09                       846563
# 1        steam            1.201810e+09                      1939027
# 2         xbox            4.923138e+09                       351111
#
#    ratio_nb_achiv_finish_and_nb_total_achiv
# 0                               8791.537770
# 1                                619.800474
# 2                              14021.598600

# %%
nb_achivements_finished_by_player = history_achievement_game_merge.groupby(['playerid','plateforme']).size().reset_index(name='nb_achivement_by_player')
nb_achivements_finished_by_player = pd.merge(left=taux_achievement_by_plateforme[['plateforme', 'nb_achivement_by_plateforme']], right=nb_achivements_finished_by_player, on='plateforme')
nb_achivements_finished_by_player['nb_achivements_finished_by_player_rate'] = nb_achivements_finished_by_player['nb_achivement_by_player'] / nb_achivements_finished_by_player['nb_achivement_by_plateforme']

nb_achivements_finished_by_player.sort_values(by='nb_achivements_finished_by_player_rate', ascending=False).head(50)
# Out:
#         plateforme  nb_achivement_by_plateforme                 playerid  \
# 7704         steam                      1939027  76561198298591193_steam
# 14821         xbox                       351111              848727_xbox
# 14811         xbox                       351111              848581_xbox
# 14818         xbox                       351111              848676_xbox
# 14780         xbox                       351111              848079_xbox
# 10570         xbox                       351111             2193927_xbox
# 14814         xbox                       351111              848604_xbox
# 2355   playstation                       846563      3065998_playstation
# 14819         xbox                       351111              848677_xbox
# 11632         xbox                       351111             4685534_xbox
# 10206         xbox                       351111             1358636_xbox
# 14815         xbox                       351111              848645_xbox
# ...

# %% [markdown]
# ##### Nombre d'achievement terminé par date

# %%
achievement_finish_by_date = achievement_finish.groupby(['date_acquired', 'plateforme']).size().reset_index(name='nb_achievement_by_date')
achievement_finish_by_date.sort_values(by='nb_achievement_by_date', ascending=False).head(50)
# Out:
#                date_acquired plateforme  nb_achievement_by_date
# 28213729 2021-11-27 21:41:27      steam                   10979
# 31973232 2023-01-30 16:04:55      steam                   10979
# 21058050 2019-07-28 19:44:37      steam                   10000
# 18908809 2018-09-28 07:05:54      steam                   10000
# 18908806 2018-09-28 07:05:52      steam                   10000
# 18908810 2018-09-28 07:05:55      steam                   10000
# 18908808 2018-09-28 07:05:53      steam                   10000
# 28213739 2021-11-27 21:42:22      steam                    9821
# 35624106 2024-05-08 14:34:22      steam                    9821
# 17357032 2018-02-17 01:51:12      steam                    9818
# 35624097 2024-05-08 14:32:36      steam                    5394
# 28213708 2021-11-27 21:39:26      steam                    5394
# 17645986 2018-03-28 14:46:30      steam                    5001
# 35951119 2024-06-26 05:22:57      steam                    5001
# ...

# %%
#Fichiers de sortie
finish_achivement_rate.to_csv('out/rate_achievement/finish_achivement_rate.csv', index = False)
taux_achievement_by_plateforme.to_csv('out/rate_achievement/taux_achievement_by_plateforme.csv', index = False)
#taux_achievement_by_game.to_csv('out/rate_achievement/taux_achievement_by_game.csv', index = False)
rate_achivement_by_player.to_csv('out/rate_achievement/rate_achivement_by_player.csv', index = False)
nb_achivements_finished_by_player.to_csv('out/rate_achievement/nb_achivements_finished_by_player.csv', index = False)
achievement_finish_by_date.to_csv('out/rate_achievement/achievement_finish_by_date.csv', index = False)

# %% [markdown]
# ##### Est-ce que les joueurs qui achètent beaucoup de jeux vont acheter des jeux plus chers que les autres ?

# %%
#Jointure des dataset purchased_games et prix
purchased_games_price_join = pd.merge(left=prices_usd[['gameid','usd']], right=purchased_games_explode_library, on='gameid', how='inner')
purchased_games_price_join.head()
# Out:
#                gameid    usd            playerid   plateforme  games_bought
# 0  746067_playstation  59.99  298261_playstation  playstation         182.0
# 1  746067_playstation  59.99   14298_playstation  playstation         756.0
# 2  746067_playstation  59.99  331411_playstation  playstation         436.0
# 3  746067_playstation  59.99  421002_playstation  playstation         620.0
# 4  746067_playstation  59.99  420407_playstation  playstation         270.0

# %%
#somme des prix des jeux acheté par nombre de jeux achetés
sum_price_brouhgt_by_player =  purchased_games_price_join.groupby(['playerid', 'games_bought'])['usd'].sum().reset_index(name = 'sum_bought_by_player').sort_values(by='games_bought', ascending=False)
sum_price_brouhgt_by_player['plateforme'] = sum_price_brouhgt_by_player['playerid'].str.split('_').str[1]
sum_price_brouhgt_by_player.head(50)
# Out:
#                        playerid  games_bought  sum_bought_by_player  \
# 90532   76561198094227663_steam       32463.0                  0.99
# 80350   76561197962473290_steam       28196.0                  1.99
# 81167   76561197976968076_steam       25707.0                  1.99
# 84479   76561198027214426_steam       25100.0                  1.99
# 112291  76561198842864763_steam       25085.0                  1.99
# 80854   76561197970825215_steam       25041.0                  1.99
# 81282   76561197979667190_steam       24170.0                  1.99
# 85235   76561198037809069_steam       22844.0                  0.99
# 114294  76561198890581618_steam       22465.0                  1.99
# 106983  76561198367471798_steam       21910.0                  1.99
# 85814   76561198044387084_steam       21717.0                  1.99
# 91248   76561198102767019_steam       21406.0                  0.99
# 81996   76561197992548975_steam       21285.0                  1.99
# ...

# %%
#Fichiers de sortie
sum_price_brouhgt_by_player.to_csv('out/price_and_number_sale/price_brouhgt_by_player_sum.csv', index=False)

# %% [markdown]
# #### Review

# %% [markdown]
# #### Nombre d’avis par jeu ? par genre ? par pays ? par joueur ? (steam)

# %%
#jointure des dataset reviews, games et players
games_review_join = pd.merge(reviews[['reviewid','playerid','gameid']], games[['gameid', 'title', 'main_genre']], on='gameid', how='left')
players_games_review_join = pd.merge(games_review_join, players[['playerid','country']], on='playerid', how='left')

players_games_review_join.head(50)
# Out:
#     reviewid                 playerid         gameid  \
# 0     639543  76561198796340888_steam      730_steam
# 1     639544  76561198028706627_steam   393380_steam
# 2     639545  76561198028706627_steam       10_steam
# 3     639546  76561198049356580_steam   469600_steam
# 4     639547  76561198272817436_steam      730_steam
# 5     639548  76561198399037664_steam   271590_steam
# 6     639549  76561198399037664_steam   578080_steam
# 7     639550  76561198399037664_steam   601150_steam
# 8     639551  76561198891812676_steam   359550_steam
# 9     639552  76561198891812676_steam      730_steam
# 10    639553  76561198081780274_steam   105600_steam
# 11    639554  76561198081780274_steam   306130_steam
# 12    639555  76561198081780274_steam    72850_steam
# 13    639556  76561198242587926_steam   346110_steam
# 14    639557  76561198177079007_steam      570_steam
# 15    639558  76561198177079007_steam   582010_steam
# 16    639559  76561198128975537_steam   733070_steam
# ...

# %%
#Nombre de revue par genre
review_by_genre= players_games_review_join.groupby(['main_genre'])['reviewid'].size().reset_index(name='nb_review').sort_values(by='nb_review', ascending=False)

#taux de revue par pays
games_genre = games.copy()

review_by_genre['nb_game_by_genre'] = review_by_genre.apply(
    lambda x : games_genre[(games_genre['main_genre'] == x['main_genre']) & (games_genre['plateforme'] == 'steam')].shape[0],
    axis=1
)

review_by_genre['rate_review_by_genre'] = review_by_genre['nb_review'] / review_by_genre['nb_game_by_genre']

review_by_genre.sort_values(by='rate_review_by_genre', ascending=False)
# Out:
#                main_genre  nb_review  nb_game_by_genre  rate_review_by_genre
# 16                    RPG      37994              1539             24.687459
# 13  Massively Multiplayer       4266               173             24.658960
# 1                  Action     788019             37955             20.761929
# 17                 Racing       8932               478             18.686192
# 22               Strategy      21695              1305             16.624521
# 19             Simulation      25196              2023             12.454770
# 9            Free To Play       6808               836              8.143541
# 4        Audio Production       1045               133              7.857143
# 10       Game Development         84                11              7.636364
# 12                  Indie      64351              8525              7.548504
# 2               Adventure     138383             19419              7.126165
# ...

# %%
#Nombre de jeu unique steam acheté
nb_purchased_games_steam_by_gameid = purchased_games_explode_library[purchased_games_explode_library['plateforme'] == 'steam'].groupby('gameid')['games_bought'].sum().reset_index()
nb_purchased_games_steam_by_gameid.head()
# Out:
#            gameid  games_bought
# 0   1000010_steam     2485262.0
# 1   1000030_steam     3213513.0
# 2   1000080_steam     1125637.0
# 3     10000_steam       46549.0
# 4   1000360_steam      297045.0

# %%
#Nombre de revue par jeu
review_by_jeu = players_games_review_join.groupby(['gameid','title','main_genre'])['reviewid'].size().reset_index(name='nb_review').sort_values(by='nb_review', ascending=False)
review_by_jeu = pd.merge(left=review_by_jeu, right=nb_purchased_games_steam_by_gameid, on='gameid', how='left')
review_by_jeu['review_by_game_rate'] = review_by_jeu['nb_review'] / review_by_jeu['games_bought']

#review_by_jeu = review_by_jeu.replace(np.nan, 'Null')
review_by_jeu.head(50).sort_values(by='review_by_game_rate', ascending=False)
# Out:
#            gameid                            title main_genre  nb_review  \
# 13   553850_steam                    HELLDIVERS™ 2     Action       6154
# 44   107410_steam                           Arma 3     Action       2642
# 43   377160_steam                        Fallout 4        RPG       2666
# 6    252490_steam                             Rust     Action       8370
# 15   292030_steam         The Witcher 3: Wild Hunt        RPG       5509
# 28   221100_steam                             DayZ     Action       3584
# 40   374320_steam                  DARK SOULS™ III     Action       2866
# 11   381210_steam                 Dead by Daylight     Action       6484
# 30  1086940_steam                  Baldur's Gate 3  Adventure       3508
# 8    252950_steam                   Rocket League®     Action       7142
# 0       730_steam                 Counter-Strike 2     Action      70529
# 34  1174180_steam            Red Dead Redemption 2     Action       3263
# ...

# %%
#Nombre de revue par pays
review_by_country = players_games_review_join.groupby(['country'])['reviewid'].size().reset_index(name='nb_review').sort_values(by='nb_review', ascending=False)

#suppression des pays non connus
review_by_country = review_by_country[review_by_country['country'] != 'unknown']

players_country = players.copy()

#nombre de joueur par pays
review_by_country['nb_player_by_country'] = review_by_country.apply(
    lambda x : players_country[(players_country['country'] == x['country']) & (players_country['plateforme'] == 'steam')].shape[0],
    axis=1
)

#taux de revue par pays
review_by_country['rate_review_by_country'] = review_by_country['nb_review'] / review_by_country['nb_player_by_country']

review_by_country.sort_values(by='rate_review_by_country', ascending=False).head(50)
# Out:
#                                           country  nb_review  \
# 140                                     Mauritius        390
# 32                              Brunei Darussalam        459
# 74                                        Finland      17922
# 208                                         Spain      27387
# 118                            Korea, Republic of       8038
# 90                                      Guatemala        556
# 216                     Taiwan, Province of China       4787
# 161                                          Niue        239
# 222                                       Tokelau        157
# 224                           Trinidad and Tobago        244
# 44                                          China      74917
# 97                  Holy See (Vatican City State)       2754
# 71                    Falkland Islands (Malvinas)        344
# 7                                      Antarctica       2694
# ...

# %%
#Nombre de jeu steam acheté par joueur
nb_purchased_games_steam_by_playerid = purchased_games_explode_library[purchased_games_explode_library['plateforme'] == 'steam'].groupby('playerid')['games_bought'].sum().reset_index()
nb_purchased_games_steam_by_playerid.head()
# Out:
#                   playerid  games_bought
# 0  76561197960266642_steam           0.0
# 1  76561197960269155_steam           0.0
# 2  76561197960269975_steam           0.0
# 3  76561197960270682_steam      256036.0
# 4  76561197960271084_steam           0.0

# %%
#Nombre de revues par joueur
review_by_player = players_games_review_join.groupby(['playerid'])['reviewid'].size().reset_index(name='nb_review').sort_values(by='nb_review', ascending=False)
review_by_player = pd.merge(left=review_by_player, right=nb_purchased_games_steam_by_playerid, on='playerid', how='left')
review_by_player['review_by_player_rate'] = review_by_player['nb_review'] / review_by_player['games_bought']

#review_by_player = review_by_player.replace(np.nan, 'Null')
review_by_player.head(50).sort_values(by='review_by_player_rate', ascending=False)

review_by_player[review_by_player['games_bought'].notnull()].head(50)
# Out:
#                     playerid  nb_review  games_bought  review_by_player_rate
# 2    76561198038776903_steam       4477   123232201.0               0.000036
# 4    76561198172925593_steam       3392   332588169.0               0.000010
# 8    76561198414080647_steam       2041    16957924.0               0.000120
# 11   76561198035504910_steam       1617    30030400.0               0.000054
# 12   76561198093298055_steam       1454    28313041.0               0.000051
# 16   76561198047455579_steam       1094     9054081.0               0.000121
# 21   76561198827112545_steam        940     5597956.0               0.000168
# 24   76561198007035653_steam        916           0.0                    inf
# 25   76561198185995181_steam        908     2217121.0               0.000410
# 29   76561198428702035_steam        789     3549456.0               0.000222
# 34   76561198020125851_steam        729   404693689.0               0.000002
# ...

# %%
review_by_genre.to_csv('out/review/review_by_genre.csv', index=False)
review_by_jeu.to_csv('out/review/review_by_jeu.csv', index=False)
review_by_country.to_csv('out/review/review_by_country.csv', index=False)
review_by_player.to_csv('out/review/review_by_player.csv', index=False)

# %% [markdown]
# ##### Correlation prix et nombre de vente

# %%
#Nombre de jeu acheté par les joueurs
nb_game_purchased = purchased_games_explode_library.groupby('gameid').size().reset_index(name='nb_game_bought')

#Jointure du dataset des prix et du dataset contenant le nombre de jeu acheté 
game_by_price_and_nb_bought = pd.merge(left=prices_usd[['gameid','usd','plateforme','main_genre']], right=nb_game_purchased, on='gameid', how='inner')
game_by_price_and_nb_bought
# Out:
#                    gameid    usd   plateforme            main_genre  \
# 0      746067_playstation  59.99  playstation      Action-Adventure
# 1      745787_playstation  19.99  playstation                Puzzle
# 2      751968_playstation   0.99  playstation            Simulation
# 3      747890_playstation    NaN  playstation                   NaN
# 4      587829_playstation    NaN  playstation                   NaN
# ...                   ...    ...          ...                   ...
# 10919         636686_xbox  12.49         xbox            Platformer
# 10920         637402_xbox    NaN         xbox  First Person Shooter
# 10921         636701_xbox  19.99         xbox             Adventure
# 10922         461588_xbox    NaN         xbox                   NaN
# 10923           2298_xbox    NaN         xbox                   NaN
#
#        nb_game_bought
# 0                  38
# 1                   1
# 2                   1
# 3                   7
# 4                   2
# ...

# %%
#Fichier de sortie
game_by_price_and_nb_bought.to_csv('out/game_by_price_and_nb_bought.csv', index=False)

# %%
#Suppression des outliner
game_by_price_and_nb_bought_without_outliner = game_by_price_and_nb_bought[game_by_price_and_nb_bought['nb_game_bought']<1500 ]

# %%
#violinplot du prix par plateforme
plt.figure(figsize=(10, 6))
sns.violinplot(
    data=game_by_price_and_nb_bought_without_outliner, 
    x='usd',
    y='plateforme', 
)

# Ajouter un titre et des labels
plt.title("Correlation entre le prix d'achat et la plateforme", fontsize=16)
plt.xlabel("Prix en dollar", fontsize=14)
plt.ylabel("Plateforme", fontsize=14)

# Afficher le graphique
plt.show()

# %%
#violinplot du nombre d'achat par plateforme par plateforme
plt.figure(figsize=(10, 6))
sns.violinplot(
    data=game_by_price_and_nb_bought_without_outliner, 
    x='nb_game_bought',
    y='plateforme'
)

# Ajouter un titre et des labels
plt.title("Correlation entre le nombre d'achat et la plateforme", fontsize=16)
plt.xlabel("Nombre d'achat par jeu", fontsize=14)
plt.ylabel("Plateforme", fontsize=14)

# Afficher le graphique
plt.show()

# %%
#violinplot du prix par nombre d'achat
plt.figure(figsize=(10, 6))
sns.violinplot(
    data=game_by_price_and_nb_bought_without_outliner, 
    x='usd',
    y='nb_game_bought', 
    hue='plateforme'
)

# Ajouter un titre et des labels
plt.title("Correlation entre le prix d'achat et la quantité d'achat parr jeu", fontsize=16)
plt.xlabel("Prix en dollar", fontsize=14)
plt.ylabel("Nombre d'achat par jeu", fontsize=14)

# Afficher le graphique
plt.show()
