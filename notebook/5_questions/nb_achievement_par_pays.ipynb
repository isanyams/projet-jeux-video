# %%
import pandas as pd
import ast

# %% [markdown]
# ### Nombre de titres d’achievement par pays ?

# %%
players=pd.read_csv("final/players.csv")

# %%
history=pd.read_csv("final/history.csv")

# %%
history.head()
# Out:
#    Unnamed: 0             playerid   achievementid        date_acquired  \
# 0           0  1911732_playstation  670209_5436079  2024-11-28 10:23:24
# 1           1  1911732_playstation  670209_5436078  2024-11-28 09:36:41
# 2           2  1911732_playstation  670209_5436077  2024-11-28 08:31:54
# 3           3  1911732_playstation  670209_5436076  2024-11-28 08:19:23
# 4           4  1911732_playstation  658551_5368954  2024-10-05 13:12:35
#
#     plateforme  acquired_year
# 0  playstation           2024
# 1  playstation           2024
# 2  playstation           2024
# 3  playstation           2024
# 4  playstation           2024

# %%
# reduire le nombre de colonnes 

history=history[['playerid', 'achievementid']]
history.head()
# Out:
#               playerid   achievementid
# 0  1911732_playstation  670209_5436079
# 1  1911732_playstation  670209_5436078
# 2  1911732_playstation  670209_5436077
# 3  1911732_playstation  670209_5436076
# 4  1911732_playstation  658551_5368954

# %%
players.head()
# Out:
#    Unnamed: 0             playerid             country   plateforme  created  \
# 0           0  2744567_playstation             Croatia  playstation  unknown
# 1           1   328452_playstation       United States  playstation  unknown
# 2           2  2521482_playstation      United Kingdom  playstation  unknown
# 3           3   390175_playstation  Korea, Republic of  playstation  unknown
# 4           4  4348945_playstation  Russian Federation  playstation  unknown
#
#    created_year
# 0           NaN
# 1           NaN
# 2           NaN
# 3           NaN
# 4           NaN

# %%
# reduire le nombre de colonnes pour question de memoire ordinateur et faire le merge

players=players[['playerid', 'country']]
players.head()
# Out:
#               playerid             country
# 0  2744567_playstation             Croatia
# 1   328452_playstation       United States
# 2  2521482_playstation      United Kingdom
# 3   390175_playstation  Korea, Republic of
# 4  4348945_playstation  Russian Federation

# %%
# merge player et history sur le playerid 

players_history=players.merge(
  history,
  left_on =['playerid'],
  right_on =['playerid'],
  how='left'    
)

# %%
players_history.head()
# Out:
#               playerid             country achievementid
# 0  2744567_playstation             Croatia           NaN
# 1   328452_playstation       United States           NaN
# 2  2521482_playstation      United Kingdom           NaN
# 3   390175_playstation  Korea, Republic of           NaN
# 4  4348945_playstation  Russian Federation           NaN

# %%
players_history.shape
# Out:
# (46520773, 3)

# %%
players_history.isnull().sum()
# Out:
# playerid               0
# country                0
# achievementid    1040911
# dtype: int64

# %% [markdown]
# ### Nombre d'achievements uniques par pays

# %%
achievements_per_country = players_history.groupby("country")["achievementid"].nunique().reset_index().sort_values('achievementid', ascending=False)

# %%
achievements_per_country
# Out:
#            country  achievementid
# 82         Germany         863526
# 248        unknown         841988
# 234  United States         584945
# 111          Japan         579918
# 30          Brazil         501361
# ..             ...            ...
# 197     Seychelles              0
# 112         Jersey              0
# 195        Senegal              0
# 116       Kiribati              0
# 125        Liberia              0
#
# [250 rows x 2 columns]

# %% [markdown]
# ### Nombre total d'achievements par pays

# %%
# cela me paraît plus juste pour analyser la question initiale ( dans un pays nous pouvons avoir plusierus joueurs
# qui ont réalisé le meme achievement) 


nb_achievement_country = (players_history
    .groupby(['country']) 
    .count()                                
    .reset_index()            
    .sort_values(['achievementid'], ascending=[False]) 
#     .groupby('country')                  
#     .head(10)                              
)

nb_achievement_country
# Out:
#                    country  playerid  achievementid
# 248                unknown  18101397       17655450
# 234          United States   5747358        5637801
# 82                 Germany   2569950        2542343
# 233         United Kingdom   2487338        2438708
# 30                  Brazil   1675037        1624431
# ..                     ...       ...            ...
# 112                 Jersey        26              0
# 195                Senegal        29              0
# 116               Kiribati        31              0
# 193  Sao Tome and Principe         8              0
# 125                Liberia        19              0
#
# [250 rows x 3 columns]

# %%
nb_achievement_country.columns = ["country","nb_of_players", "nb_of_achievements"]

nb_achievement_country
# Out:
#                    country  nb_of_players  nb_of_achievements
# 248                unknown       18101397            17655450
# 234          United States        5747358             5637801
# 82                 Germany        2569950             2542343
# 233         United Kingdom        2487338             2438708
# 30                  Brazil        1675037             1624431
# ..                     ...            ...                 ...
# 112                 Jersey             26                   0
# 195                Senegal             29                   0
# 116               Kiribati             31                   0
# 193  Sao Tome and Principe              8                   0
# 125                Liberia             19                   0
#
# [250 rows x 3 columns]

# %% [markdown]
# ### Normalisation après conseil de Victor

# %%
nb_achievement_country["avg_achievement_per_player"]=(nb_achievement_country["nb_of_achievements"]/nb_achievement_country["nb_of_players"]).round(2)

nb_achievement_country.head()
# Out:
#             country  nb_of_players  nb_of_achievements  \
# 248         unknown       18101397            17655450
# 234   United States        5747358             5637801
# 82          Germany        2569950             2542343
# 233  United Kingdom        2487338             2438708
# 30           Brazil        1675037             1624431
#
#      avg_achievement_per_player
# 248                        0.98
# 234                        0.98
# 82                         0.99
# 233                        0.98
# 30                         0.97

# %%
# trier avg_nb_achievement par joueur

nb_achievement_country.sort_values(['avg_achievement_per_player'], ascending=[False])
# Out:
#                      country  nb_of_players  nb_of_achievements  \
# 129               Luxembourg         276852              276558
# 1                    Albania          84565               84295
# 56                    Cyprus          66146               65900
# 68                   Estonia          66531               66028
# 13                   Austria         245847              243324
# ..                       ...            ...                 ...
# 241  Virgin Islands, British             82                   0
# 22                     Benin             10                   0
# 245                    Yemen             70                   0
# 6                   Anguilla             24                   0
# 125                  Liberia             19                   0
#
#      avg_achievement_per_player
# 129                        1.00
# 1                          1.00
# 56                         1.00
# 68                         0.99
# ...

# %%
# enregistrer en csv 

nb_achievement_country.to_csv("powerbi/nb_achievement_par_pays.csv")
